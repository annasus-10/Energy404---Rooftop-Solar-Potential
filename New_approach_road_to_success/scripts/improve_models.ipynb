# %%
import pandas as pd
import numpy as np
from pathlib import Path

from sklearn.model_selection import GroupKFold, GridSearchCV
from sklearn.metrics import mean_absolute_error

from lightgbm import LGBMRegressor
from xgboost import XGBRegressor

# === Load Dataset ===
DATA = Path("C:/Users/User/Desktop/ML/Project/solar-potential-analysis-github-setup/New_approach/dataset/cleaned_datasets/top20_balanced_sample.parquet" )
df = pd.read_parquet(DATA)

# === Define Features ===
TARGET = "kWh_per_m2"
CAT = ["BuildingType"]
NUM = [
    "tilt", "tilt2", "tilt_sin", "tilt_cos",
    "GHI_kWh_per_m2_day", "AvgTemp_C",
    "ClearnessIndex", "Precip_mm_per_day"
]

X = df[NUM + CAT]
y = df[TARGET]

# ✅ Convert categorical columns to 'category' dtype
for col in CAT:
    X[col] = X[col].astype("category")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_37096\1599172594.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = X[col].astype("category")

# %%
from sklearn.model_selection import GroupKFold

# --- Simulate RepeatedGroupKFold for compatibility ---
def repeated_group_kfold(X, y, groups, n_splits=5, n_repeats=2, random_state=42):
    rng = np.random.default_rng(random_state)
    all_splits = []
    for r in range(n_repeats):
        gkf = GroupKFold(n_splits=n_splits)
        shuffled_groups = rng.permutation(np.unique(groups))
        group_map = {g: i for i, g in enumerate(shuffled_groups)}
        sorted_groups = np.array([group_map[g] for g in groups])
        all_splits.extend(list(gkf.split(X, y, sorted_groups)))
    return all_splits

cv_splits = repeated_group_kfold(X, y, df["City"], n_splits=5, n_repeats=2)

# --- Base LGBM Model ---
base_lgbm = LGBMRegressor(
    objective='mae',
    n_estimators=1000,
    learning_rate=0.05,
    subsample=0.9,
    colsample_bytree=0.8,
    random_state=42
)

# --- Parameter Grid ---
param_grid = {
    'num_leaves': [15, 31, 63],
    'min_child_samples': [5, 20, 50],
    'lambda_l1': [0, 0.1, 1.0],
    'lambda_l2': [0, 0.1, 1.0],
    'max_depth': [-1, 5, 10]
}

grid = GridSearchCV(
    base_lgbm,
    param_grid,
    cv=cv_splits,
    n_jobs=-1,
    scoring='neg_mean_absolute_error',
    verbose=1
)

grid.fit(X, y)
print("✅ Best params:", grid.best_params_)
print("✅ Best mean MAE:", -grid.best_score_)
# Out:
# Fitting 10 folds for each of 243 candidates, totalling 2430 fits
# [LightGBM] [Warning] lambda_l1 is set=1.0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0
# [LightGBM] [Warning] lambda_l2 is set=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [LightGBM] [Warning] lambda_l1 is set=1.0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0
# [LightGBM] [Warning] lambda_l2 is set=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037788 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1108
# [LightGBM] [Info] Number of data points in the train set: 958580, number of used features: 9
# [LightGBM] [Info] Start training from score 273.000366
# ✅ Best params: {'lambda_l1': 1.0, 'lambda_l2': 1.0, 'max_depth': -1, 'min_child_samples': 5, 'num_leaves': 15}
# ✅ Best mean MAE: 19.27580144365488

# %%
from sklearn.model_selection import GroupKFold
from sklearn.metrics import mean_absolute_error
import numpy as np

# === Define Models ===
xgb = XGBRegressor(
    objective='reg:squarederror',
    n_estimators=800,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.9,
    colsample_bytree=0.8,
    random_state=42
)

lgb = LGBMRegressor(
    objective='mae',
    n_estimators=1000,
    learning_rate=0.05,
    num_leaves=31,
    subsample=0.9,
    colsample_bytree=0.8,
    random_state=42
)

# === Cross-Validation ===
cv = GroupKFold(n_splits=3)
mae_scores = []

for fold, (train_idx, val_idx) in enumerate(cv.split(X, y, groups=df["City"]), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
    
    xgb.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=False)
    lgb.fit(X_train, y_train, eval_set=[(X_val, y_val)], early_stopping_rounds=100, verbose=False)
    
    pred_xgb = xgb.predict(X_val)
    pred_lgb = lgb.predict(X_val)
    
    # Weighted blend — tweak if needed
    blended = 0.6 * pred_xgb + 0.4 * pred_lgb
    mae = mean_absolute_error(y_val, blended)
    mae_scores.append(mae)
    print(f"Fold {fold} MAE = {mae:.3f}")

print(f"\n✅ Mean Ensemble MAE: {np.mean(mae_scores):.3f} ± {np.std(mae_scores):.3f}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\data.py:407, in pandas_feature_info(data, meta, feature_names, feature_types, enable_categorical)
#     406 try:
# --> 407     new_feature_types.append(_pandas_dtype_mapper[dtype.name])
#     408 except KeyError:
#
# KeyError: 'category'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 34
#      31 X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
#      32 y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
# ---> 34 xgb.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=False)
#      35 lgb.fit(X_train, y_train, eval_set=[(X_val, y_val)], early_stopping_rounds=100, verbose=False)
#      37 pred_xgb = xgb.predict(X_val)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\core.py:774, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     772 for k, arg in zip(sig.parameters, args):
#     773     kwargs[k] = arg
# --> 774 return func(**kwargs)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\sklearn.py:1340, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1337 model, feature_types = get_model_categories(X, model, self.feature_types)
#    1339 evals_result: EvalsLog = {}
# -> 1340 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1341     missing=self.missing,
#    1342     X=X,
#    1343     y=y,
#    1344     group=None,
#    1345     qid=None,
#    1346     sample_weight=sample_weight,
#    1347     base_margin=base_margin,
#    1348     feature_weights=feature_weights,
#    1349     eval_set=eval_set,
#    1350     sample_weight_eval_set=sample_weight_eval_set,
#    1351     base_margin_eval_set=base_margin_eval_set,
#    1352     eval_group=None,
#    1353     eval_qid=None,
#    1354     create_dmatrix=self._create_dmatrix,
#    1355     enable_categorical=self.enable_categorical,
#    1356     feature_types=feature_types,
#    1357 )
#    1359 if callable(self.objective):
#    1360     obj: Optional[Objective] = _objective_decorator(self.objective)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\sklearn.py:701, in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, feature_types)
#     696 """Convert array_like evaluation matrices into DMatrix. Perform sanity checks on the
#     697 way.
#     698
#     699 """
#     700 # Feature_types contains the optional reference categories from the booster object.
# --> 701 train_dmatrix = create_dmatrix(
#     702     data=X,
#     703     label=y,
#     704     group=group,
#     705     qid=qid,
#     706     weight=sample_weight,
#     707     base_margin=base_margin,
#     708     feature_weights=feature_weights,
#     709     missing=missing,
#     710     enable_categorical=enable_categorical,
#     711     feature_types=feature_types,
#     712     ref=None,
#     713 )
#     715 n_validation = 0 if eval_set is None else len(eval_set)
#     716 if hasattr(train_dmatrix, "get_categories"):
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\sklearn.py:1254, in XGBModel._create_dmatrix(self, ref, **kwargs)
#    1252 if _can_use_qdm(self.tree_method, self.device) and self.booster != "gblinear":
#    1253     try:
# -> 1254         return QuantileDMatrix(
#    1255             **kwargs, ref=ref, nthread=self.n_jobs, max_bin=self.max_bin
#    1256         )
#    1257     except TypeError:  # `QuantileDMatrix` supports lesser types than DMatrix
#    1258         pass
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\core.py:774, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     772 for k, arg in zip(sig.parameters, args):
#     773     kwargs[k] = arg
# --> 774 return func(**kwargs)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\core.py:1768, in QuantileDMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, max_bin, ref, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical, max_quantile_batches, data_split_mode)
#    1748     if any(
#    1749         info is not None
#    1750         for info in (
#    (...)   1761         )
#    1762     ):
#    1763         raise ValueError(
#    1764             "If data iterator is used as input, data like label should be "
#    1765             "specified as batch argument."
#    1766         )
# -> 1768 self._init(
#    1769     data,
#    1770     ref=ref,
#    1771     label=label,
#    1772     weight=weight,
#    1773     base_margin=base_margin,
#    1774     group=group,
#    1775     qid=qid,
#    1776     label_lower_bound=label_lower_bound,
#    1777     label_upper_bound=label_upper_bound,
#    1778     feature_weights=feature_weights,
#    1779     feature_names=feature_names,
#    1780     feature_types=feature_types,
#    1781     enable_categorical=enable_categorical,
#    1782     max_quantile_blocks=max_quantile_batches,
#    1783 )
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\core.py:1832, in QuantileDMatrix._init(self, data, ref, enable_categorical, max_quantile_blocks, **meta)
#    1817 config = make_jcargs(
#    1818     nthread=self.nthread,
#    1819     missing=self.missing,
#    1820     max_bin=self.max_bin,
#    1821     max_quantile_blocks=max_quantile_blocks,
#    1822 )
#    1823 ret = _LIB.XGQuantileDMatrixCreateFromCallback(
#    1824     None,
#    1825     it.proxy.handle,
#    (...)   1830     ctypes.byref(handle),
#    1831 )
# -> 1832 it.reraise()
#    1833 # delay check_call to throw intermediate exception first
#    1834 _check_call(ret)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\core.py:617, in DataIter.reraise(self)
#     615 exc = self._exception
#     616 self._exception = None
# --> 617 raise exc
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\core.py:598, in DataIter._handle_exception(self, fn, dft_ret)
#     595     return dft_ret
#     597 try:
# --> 598     return fn()
#     599 except Exception as e:  # pylint: disable=broad-except
#     600     # Defer the exception in order to return 0 and stop the iteration.
#     601     # Exception inside a ctype callback function has no effect except
#     602     # for printing to stderr (doesn't stop the execution).
#     603     tb = sys.exc_info()[2]
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\core.py:685, in DataIter._next_wrapper.<locals>.<lambda>()
#     683     self._temporary_data = None
#     684 # pylint: disable=not-callable
# --> 685 return self._handle_exception(lambda: int(self.next(input_data)), 0)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\data.py:1632, in SingleBatchInternalIter.next(self, input_data)
#    1630     return False
#    1631 self.it += 1
# -> 1632 input_data(**self.kwargs)
#    1633 return True
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\core.py:774, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     772 for k, arg in zip(sig.parameters, args):
#     773     kwargs[k] = arg
# --> 774 return func(**kwargs)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\core.py:665, in DataIter._next_wrapper.<locals>.input_data(data, feature_names, feature_types, **kwargs)
#     663     new, feature_names, feature_types = self._temporary_data
#     664 else:
# --> 665     new, feature_names, feature_types = _proxy_transform(
#     666         data,
#     667         feature_names,
#     668         feature_types,
#     669         self._enable_categorical,
#     670     )
#     671 # Stage the data, meta info are copied inside C++ MetaInfo.
#     672 self._temporary_data = (new, feature_names, feature_types)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\data.py:1685, in _proxy_transform(data, feature_names, feature_types, enable_categorical)
#    1683     return df_pa, feature_names, feature_types
#    1684 if _is_pandas_df(data):
# -> 1685     df, feature_names, feature_types = _transform_pandas_df(
#    1686         data, enable_categorical, feature_names, feature_types
#    1687     )
#    1688     return df, feature_names, feature_types
#    1689 raise TypeError("Value type is not supported for data iterator:" + str(type(data)))
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\data.py:662, in _transform_pandas_df(data, enable_categorical, feature_names, feature_types, meta)
#     659     raise ValueError(f"DataFrame for {meta} cannot have multiple columns")
#     661 feature_types, ref_categories = get_ref_categories(feature_types)
# --> 662 feature_names, feature_types = pandas_feature_info(
#     663     data, meta, feature_names, feature_types, enable_categorical
#     664 )
#     666 arrays = pandas_transform_data(data)
#     667 return (
#     668     PandasTransformed(arrays, ref_categories=ref_categories),
#     669     feature_names,
#     670     feature_types,
#     671 )
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\data.py:409, in pandas_feature_info(data, meta, feature_names, feature_types, enable_categorical)
#     407             new_feature_types.append(_pandas_dtype_mapper[dtype.name])
#     408         except KeyError:
# --> 409             _invalid_dataframe_dtype(data)
#     411 if feature_types is None and meta is None:
#     412     feature_types = new_feature_types
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\data.py:372, in _invalid_dataframe_dtype(data)
#     370 type_err = "DataFrame.dtypes for data must be int, float, bool or category."
#     371 msg = f"""{type_err} {_ENABLE_CAT_ERR} {err}"""
# --> 372 raise ValueError(msg)
#
# ValueError: DataFrame.dtypes for data must be int, float, bool or category. When categorical type is supplied, the experimental DMatrix parameter`enable_categorical` must be set to `True`.  Invalid columns:BuildingType: category

# %%
best_lgbm_mae = -grid.best_score_
ensemble_mae = np.mean(mae_scores)

print(f"📊 Baseline LGBM (from previous run): 17.23 kWh/m²")
print(f"✅ Tuned LGBM MAE: {best_lgbm_mae:.3f} kWh/m²")
print(f"🤝 Ensemble MAE: {ensemble_mae:.3f} kWh/m²")
print(f"📉 Improvement: {17.23 - ensemble_mae:.2f} kWh/m² (~{(17.23 - ensemble_mae)/17.23*100:.1f}%)")
