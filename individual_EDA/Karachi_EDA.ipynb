# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('karachi_rooftop_solar_potential.csv')
df.head()
# Out:
#                                    uuid     City  Surface_area  \
# 0  1cbf6d20-5926-4fff-8817-2afb7d8b9803  Karachi         75.93
# 1  ed9e4c08-8c4e-425f-89d5-2d7ed8149fc2  Karachi         73.05
# 2  4093dab6-efae-48f5-8441-7342d5756467  Karachi         77.26
# 3  c26e8c10-cf31-4bc3-a6c5-a1956b975d8e  Karachi        288.77
# 4  266e1e1d-4630-4e18-ac63-6a3b80e416ee  Karachi          6.65
#
#    Potential_installable_area  Peak_installable_capacity  \
# 0                       10.41                       2.02
# 1                        6.07                       1.18
# 2                       27.13                       5.26
# 3                      110.14                      21.35
# 4                        0.00                       0.00
#
#    Energy_potential_per_year     Assumed_building_type  Estimated_tilt  \
# 0                    3136.49     peri-urban settlement             5.0
# 1                    1827.58     peri-urban settlement             5.0
# 2                    8383.77                commercial             5.0
# 3                   33533.84  multi family residential             5.0
# 4                       0.00     peri-urban settlement             5.0
#
#    Estimated_building_height  Estimated_capacity_factor  \
# 0                      14.76                     1553.0
# 1                      21.47                     1553.0
# 2                       8.61                     1593.0
# 3                      14.02                     1571.0
# 4                       4.92                        NaN
#
#    Unit_installation_price Comment
# 0                      NaN     NaN
# 1                      NaN     NaN
# 2                      NaN     NaN
# 3                      NaN     NaN
# 4                      NaN     NaN

# %%
df.tail()
# Out:
#                                         uuid     City  Surface_area  \
# 296683  d1ca6cc5-4069-4d5b-861a-990e0c48476d  Karachi        613.99
# 296684  e46e82f7-a13d-4004-9374-754926a67c8e  Karachi       1739.47
# 296685  3b1e8599-0447-490d-8188-52da68926e16  Karachi       1164.05
# 296686  e0828b35-a70b-4bb0-af4d-403b3ce4b087  Karachi       2381.37
# 296687  d523bff1-8f88-4d97-93ef-4adadb7d1ecc  Karachi       2242.00
#
#         Potential_installable_area  Peak_installable_capacity  \
# 296683                      246.13                      47.70
# 296684                     1171.88                     227.12
# 296685                      315.77                      61.20
# 296686                     1343.98                     260.73
# 296687                      614.19                     119.15
#
#         Energy_potential_per_year     Assumed_building_type  Estimated_tilt  \
# 296683                   75988.56                commercial            5.00
# 296684                  365660.28                industrial            5.87
# 296685                   96997.77                    public            5.00
# 296686                  407786.25                commercial            9.10
# 296687                  187666.42  multi family residential            5.00
#
#         Estimated_building_height  Estimated_capacity_factor  \
# 296683                      12.41                     1593.0
# 296684                       9.40                     1610.0
# 296685                      61.38                     1585.0
# 296686                      17.92                     1564.0
# 296687                      74.17                     1575.0
#
#         Unit_installation_price Comment
# 296683                      NaN     NaN
# 296684                      NaN     NaN
# 296685                      NaN     NaN
# 296686                      NaN     NaN
# 296687                      NaN     NaN

# %%
df.shape
# Out:
# (296688, 12)

# %%
df.describe()
# Out:
#         Surface_area  Potential_installable_area  Peak_installable_capacity  \
# count  296688.000000               296688.000000              296688.000000
# mean      133.891076                   53.208950                  10.322351
# std       226.406296                  131.372906                  25.485128
# min         0.000000                    0.000000                   0.000000
# 25%        30.140000                    5.600000                   1.090000
# 50%        72.040000                   19.290000                   3.740000
# 75%       159.700000                   55.420000                  10.750000
# max     25725.350000                13364.400000                2595.290000
#
#        Energy_potential_per_year  Estimated_tilt  Estimated_building_height  \
# count               2.966880e+05   296688.000000              295719.000000
# mean                1.632300e+04        4.929899                  10.769128
# std                 4.033430e+04        2.162735                   6.260252
# min                 0.000000e+00        0.000000                  -7.400000
# 25%                 1.711575e+03        5.000000                   6.380000
# 50%                 5.899200e+03        5.000000                   9.730000
# 75%                 1.696318e+04        5.000000                  13.980000
# max                 4.056431e+06       53.020000                  99.550000
#
#        Estimated_capacity_factor  Unit_installation_price
# count              263704.000000                      0.0
# mean                 1577.844143                      NaN
# std                    22.132807                      NaN
# min                   806.000000                      NaN
# 25%                  1571.000000                      NaN
# 50%                  1578.000000                      NaN
# 75%                  1593.000000                      NaN
# max                  1666.390000                      NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296688 entries, 0 to 296687
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   uuid                        296688 non-null  object
#  1   City                        296688 non-null  object
#  2   Surface_area                296688 non-null  float64
#  3   Potential_installable_area  296688 non-null  float64
#  4   Peak_installable_capacity   296688 non-null  float64
#  5   Energy_potential_per_year   296688 non-null  float64
#  6   Assumed_building_type       296688 non-null  object
#  7   Estimated_tilt              296688 non-null  float64
#  8   Estimated_building_height   295719 non-null  float64
#  9   Estimated_capacity_factor   263704 non-null  float64
#  10  Unit_installation_price     0 non-null       float64
#  11  Comment                     410 non-null     object
# dtypes: float64(8), object(4)
# memory usage: 27.2+ MB

# %%
df.columns
# Out:
# Index(['uuid', 'City', 'Surface_area', 'Potential_installable_area',
#        'Peak_installable_capacity', 'Energy_potential_per_year',
#        'Assumed_building_type', 'Estimated_tilt', 'Estimated_building_height',
#        'Estimated_capacity_factor', 'Unit_installation_price', 'Comment'],
#       dtype='object')

# %%
df.nunique().sort_values()
# Out:
# Unit_installation_price            0
# City                               1
# Comment                            2
# Assumed_building_type              5
# Estimated_capacity_factor        982
# Estimated_tilt                  1893
# Estimated_building_height       4594
# Peak_installable_capacity      10904
# Potential_installable_area     30492
# Surface_area                   50767
# Energy_potential_per_year     247882
# uuid                          296688
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df.isnull().sum())
# Out:
# uuid                               0
# City                               0
# Surface_area                       0
# Potential_installable_area         0
# Peak_installable_capacity          0
# Energy_potential_per_year          0
# Assumed_building_type              0
# Estimated_tilt                     0
# Estimated_building_height        969
# Estimated_capacity_factor      32984
# Unit_installation_price       296688
# Comment                       296278
# dtype: int64

# %%
rules = {
    'Surface_area': (0, np.inf),
    'Potential_installable_area': (0, np.inf),
    'Peak_installable_capacity': (0, np.inf),      # kWp
    'Energy_potential_per_year': (0, np.inf),      # kWh/year
    'Estimated_tilt': (0, 90),                     # degrees
    'Estimated_building_height': (0, np.inf),
    'Estimated_capacity_factor': (0, 1),           # 0–1
    'Estimated_installation_efficiency': (0, 1),   # 0–1
    'Unit_installation_price': (0, np.inf)
}
violations = {}
for col,(lo,hi) in rules.items():
    if col in df.columns:
        violations[col] = df[(df[col].notna()) & ((df[col]<lo)|(df[col]>hi))].shape[0]
violations
# Out:
# {'Surface_area': 0,
#  'Potential_installable_area': 0,
#  'Peak_installable_capacity': 0,
#  'Energy_potential_per_year': 0,
#  'Estimated_tilt': 0,
#  'Estimated_building_height': 477,
#  'Estimated_capacity_factor': 263704,
#  'Unit_installation_price': 0}

# %%
# Drop useless columns
df.drop(['Unit_installation_price', 'City', 'Comment'], axis=1, inplace=True)

# %%
df[df['Estimated_building_height'] <= 0][['Estimated_building_height']].describe()
# Out:
#        Estimated_building_height
# count                 806.000000
# mean                   -0.502742
# std                     0.886742
# min                    -7.400000
# 25%                    -0.600000
# 50%                    -0.160000
# 75%                     0.000000
# max                     0.000000

# %%
df.loc[df['Estimated_building_height'] <= 0, 'Estimated_building_height'] = np.nan

# %%
df['Estimated_building_height'].fillna(df['Estimated_building_height'].median(), inplace=True)

# %%
df['Estimated_building_height'] = df['Estimated_building_height'] / 100

# %%
df['Estimated_capacity_factor'].describe()
# Out:
# count    263704.000000
# mean       1577.844143
# std          22.132807
# min         806.000000
# 25%        1571.000000
# 50%        1578.000000
# 75%        1593.000000
# max        1666.390000
# Name: Estimated_capacity_factor, dtype: float64

# %%
df['Estimated_capacity_factor'] = df['Estimated_capacity_factor'] / 1000

# %%
df['Estimated_capacity_factor'].describe()
# Out:
# count    263704.000000
# mean          1.577844
# std           0.022133
# min           0.806000
# 25%           1.571000
# 50%           1.578000
# 75%           1.593000
# max           1.666390
# Name: Estimated_capacity_factor, dtype: float64

# %%
df['Estimated_capacity_factor'] = df['Estimated_capacity_factor'].clip(upper=1)

# %%
rules = {
    'Surface_area': (0, np.inf),
    'Potential_installable_area': (0, np.inf),
    'Peak_installable_capacity': (0, np.inf),      # kWp
    'Energy_potential_per_year': (0, np.inf),      # kWh/year
    'Estimated_tilt': (0, 90),                     # degrees
    'Estimated_building_height': (0, np.inf),
    'Estimated_capacity_factor': (0, 1),           # 0–1
    'Estimated_installation_efficiency': (0, 1),   # 0–1
    'Unit_installation_price': (0, np.inf)
}
violations = {}
for col,(lo,hi) in rules.items():
    if col in df.columns:
        violations[col] = df[(df[col].notna()) & ((df[col]<lo)|(df[col]>hi))].shape[0]
violations
# Out:
# {'Surface_area': 0,
#  'Potential_installable_area': 0,
#  'Peak_installable_capacity': 0,
#  'Energy_potential_per_year': 0,
#  'Estimated_tilt': 0,
#  'Estimated_building_height': 0,
#  'Estimated_capacity_factor': 0}

# %%
print(df.isnull().sum())
# Out:
# uuid                              0
# Surface_area                      0
# Potential_installable_area        0
# Peak_installable_capacity         0
# Energy_potential_per_year         0
# Assumed_building_type             0
# Estimated_tilt                    0
# Estimated_building_height         0
# Estimated_capacity_factor     32984
# dtype: int64

# %%
# drop missing values
df = df.dropna(subset=['Estimated_capacity_factor'])

# %%
print(df.isnull().sum())
# Out:
# uuid                          0
# Surface_area                  0
# Potential_installable_area    0
# Peak_installable_capacity     0
# Energy_potential_per_year     0
# Assumed_building_type         0
# Estimated_tilt                0
# Estimated_building_height     0
# Estimated_capacity_factor     0
# dtype: int64

# %%
sns.countplot(data=df, x='Assumed_building_type')
# Out:
# <Axes: xlabel='Assumed_building_type', ylabel='count'>

# %%
sns.displot(data = df, x = 'Peak_installable_capacity')

# %%
#Univariate Distributions

num_cols = df.select_dtypes(include=[np.number]).columns
for c in ['Surface_area','Potential_installable_area','Peak_installable_capacity',
          'Energy_potential_per_year','Estimated_tilt','Estimated_capacity_factor',
          'Estimated_installation_efficiency','Unit_installation_price',
          'installable_density','kwp_per_m2','specific_yield','capex_proxy']:
    if c in num_cols:
        df[c].plot(kind='hist', bins=30, edgecolor='white')
        plt.title(c); plt.xlabel(c); plt.show()

# %%
def iqr_flags(s, k=1.5):
    q1, q3 = s.quantile([0.25,0.75])
    iqr = q3-q1
    return ((s < q1 - k*iqr) | (s > q3 + k*iqr))

outlier_report = {}
for c in num_cols:
    flags = iqr_flags(df[c].dropna())
    outlier_report[c] = int(flags.sum())
outlier_report
# Out:
# {'Surface_area': 18941,
#  'Potential_installable_area': 24379,
#  'Peak_installable_capacity': 24377,
#  'Energy_potential_per_year': 24499,
#  'Estimated_tilt': 65781,
#  'Estimated_building_height': 6452,
#  'Estimated_capacity_factor': 27}

# %%
df.columns
# Out:
# Index(['uuid', 'Surface_area', 'Potential_installable_area',
#        'Peak_installable_capacity', 'Energy_potential_per_year',
#        'Assumed_building_type', 'Estimated_tilt', 'Estimated_building_height',
#        'Estimated_capacity_factor'],
#       dtype='object')

# %%
df['Assumed_building_type'] = df['Assumed_building_type'].astype('category').cat.codes

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 263704 entries, 0 to 296687
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   uuid                        263704 non-null  object
#  1   Surface_area                263704 non-null  float64
#  2   Potential_installable_area  263704 non-null  float64
#  3   Peak_installable_capacity   263704 non-null  float64
#  4   Energy_potential_per_year   263704 non-null  float64
#  5   Assumed_building_type       263704 non-null  int8
#  6   Estimated_tilt              263704 non-null  float64
#  7   Estimated_building_height   263704 non-null  float64
#  8   Estimated_capacity_factor   263704 non-null  float64
# dtypes: float64(7), int8(1), object(1)
# memory usage: 18.4+ MB
#                                    uuid  Surface_area  \
# 0  1cbf6d20-5926-4fff-8817-2afb7d8b9803         75.93
# 1  ed9e4c08-8c4e-425f-89d5-2d7ed8149fc2         73.05
# 2  4093dab6-efae-48f5-8441-7342d5756467         77.26
# 3  c26e8c10-cf31-4bc3-a6c5-a1956b975d8e        288.77
# 5  8195ca2e-05aa-46d9-8ab4-19dae9220f2b         37.62
#
#    Potential_installable_area  Peak_installable_capacity  \
# 0                       10.41                       2.02
# 1                        6.07                       1.18
# 2                       27.13                       5.26
# 3                      110.14                      21.35
# 5                       13.84                       2.69
#
#    Energy_potential_per_year  Assumed_building_type  Estimated_tilt  \
# 0                    3136.49                      3             5.0
# 1                    1827.58                      3             5.0
# 2                    8383.77                      0             5.0
# 3                   33533.84                      2             5.0
# 5                    4262.09                      2             5.0
#
#    Estimated_building_height  Estimated_capacity_factor
# 0                     0.1476                        1.0
# 1                     0.2147                        1.0
# 2                     0.0861                        1.0
# 3                     0.1402                        1.0
# 5                     0.1069                        1.0

# %%
t2 = 'Peak_installable_capacity'
for c in ['Surface_area','Potential_installable_area','Peak_installable_capacity',
          'Energy_potential_per_year','Estimated_tilt','Estimated_capacity_factor']:
    if c in df.columns:
        df.plot(kind='scatter', x=c, y=t2, alpha=0.4)
        plt.title(f'{c} vs {t2}')
        plt.show()

# %%
# Compute correlations (only numeric columns)
corr = df.corr(numeric_only=True)

# Set up the figure
plt.figure(figsize=(12, 8))

# Create heatmap with numbers
sns.heatmap(
    corr,
    cmap='coolwarm',       # color style
    annot=True,            # show correlation numbers
    fmt=".2f",             # format numbers to 2 decimal places
    linewidths=0.5         # thin lines between boxes
)

plt.title("Correlation Heatmap", fontsize=16)
plt.show()

# %%
corr = df[num_cols].corr(numeric_only=True)
plt.figure(figsize=(10,8))
plt.imshow(corr, cmap='coolwarm', vmin=-1, vmax=1)
plt.colorbar(); plt.title('Correlation Matrix'); plt.xticks(range(len(num_cols)), num_cols, rotation=90); plt.yticks(range(len(num_cols)), num_cols)
plt.tight_layout(); plt.show()

# Quick look at variables most correlated with each target
corr_target1 = corr['Energy_potential_per_year'].sort_values(ascending=False) if 'Energy_potential_per_year' in corr else None
corr_target2 = corr['Peak_installable_capacity'].sort_values(ascending=False) if 'Peak_installable_capacity' in corr else None
corr_target1, corr_target2
# Out:
# (Energy_potential_per_year     1.000000
#  Peak_installable_capacity     0.999853
#  Potential_installable_area    0.999834
#  Surface_area                  0.960529
#  Estimated_building_height     0.092891
#  Estimated_tilt                0.018985
#  Estimated_capacity_factor     0.002463
#  Name: Energy_potential_per_year, dtype: float64,
#  Peak_installable_capacity     1.000000
#  Potential_installable_area    0.999980
#  Energy_potential_per_year     0.999853
#  Surface_area                  0.960523
#  Estimated_building_height     0.093409
#  Estimated_tilt                0.024556
#  Estimated_capacity_factor     0.001968
#  Name: Peak_installable_capacity, dtype: float64)

# %% [markdown]
# #### The top predictors for Energy Potential per Year are: Classification
#
# 1️⃣ Peak_installable_capacity
# 2️⃣ Potential_installable_area
# 3️⃣ Surface_area
#
#
# #### The strongest correlated features with Peak Installable Capacity are: Regression
#
# 1️⃣ Potential_installable_area
# 2️⃣ Energy_potential_per_year
# 3️⃣ Surface_area
