# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_dhaka = pd.read_csv("dataset/dhaka.csv")

# %%
df_dhaka.head()
# Out:
#    OBJECTID                                  uuid              City  \
# 0         1  7a88a19a-becb-4a8d-8328-5dc2223f65cf  GreatDhakaRegion
# 1         2  366223f8-13da-4256-8f41-0a9f6ccd1149  GreatDhakaRegion
# 2         3  e7bf478f-5597-4000-80ba-bdb178d9a16a  GreatDhakaRegion
# 3         4  1ccfc6d3-6983-4d71-b787-da6376e1594e  GreatDhakaRegion
# 4         5  969731e4-8d11-4a4d-8960-8405bc2bcb9b  GreatDhakaRegion
#
#    Surface_area  Potential_installable_area  Peak_installable_capacity  \
# 0    331.500000                  189.410004                  36.779999
# 1     22.030001                    6.840000                   1.330000
# 2     23.930000                    9.230000                   1.790000
# 3     56.299999                   31.379999                   6.090000
# 4     74.290001                   34.169998                   6.630000
#
#    Energy_potential_per_year      Assumed_building_type  Estimated_tilt  \
# ...

# %%
df_dhaka.describe()
# Out:
#             OBJECTID   Surface_area  Potential_installable_area  \
# count  632745.000000  632745.000000               632745.000000
# mean   316373.000000     158.109746                   85.015346
# std    182657.892377     282.767151                  204.678266
# min         1.000000       0.000000                    0.000000
# 25%    158187.000000      57.410000                   23.360001
# 50%    316373.000000     109.379997                   49.930000
# 75%    474559.000000     186.699997                   93.459999
# max    632745.000000   42641.011719                30589.359375
#
#        Peak_installable_capacity  Energy_potential_per_year  Estimated_tilt  \
# count              632745.000000               6.327450e+05   632745.000000
# mean                   16.493019               2.041097e+04       14.012012
# std                    39.706817               5.042528e+04        6.413375
# min                     0.000000               0.000000e+00        0.000000
# ...

# %%
df_dhaka.columns
# Out:
# Index(['OBJECTID', 'uuid', 'City', 'Surface_area',
#        'Potential_installable_area', 'Peak_installable_capacity',
#        'Energy_potential_per_year', 'Assumed_building_type', 'Estimated_tilt',
#        'Estimated_building_height', 'Estimated_capacity_factor',
#        'Unit_installation_price', 'Date_added', 'Comment'],
#       dtype='object')

# %%
df_dhaka.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 632745 entries, 0 to 632744
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   OBJECTID                    632745 non-null  int64
#  1   uuid                        632745 non-null  object
#  2   City                        632745 non-null  object
#  3   Surface_area                632745 non-null  float64
#  4   Potential_installable_area  632745 non-null  float64
#  5   Peak_installable_capacity   632745 non-null  float64
#  6   Energy_potential_per_year   632745 non-null  float64
#  7   Assumed_building_type       632745 non-null  object
#  8   Estimated_tilt              632745 non-null  float64
#  9   Estimated_building_height   627490 non-null  float64
#  10  Estimated_capacity_factor   623809 non-null  float64
#  11  Unit_installation_price     0 non-null       float64
# ...

# %%
df_dhaka['Date_added'].head()
# Out:
# 0    2022-01-07T10:46:21.000
# 1    2022-01-07T10:46:21.000
# 2    2022-01-07T10:46:21.000
# 3    2022-01-07T10:46:21.000
# 4    2022-01-07T10:46:21.000
# Name: Date_added, dtype: object

# %%
df_dhaka=df_dhaka.drop('Unit_installation_price', axis="columns")

# %%
df_dhaka=df_dhaka.drop("Comment", axis='columns')

# %%
df_dhaka=df_dhaka.drop("uuid", axis='columns')

# %%
df_dhaka=df_dhaka.drop("Date_added", axis='columns')

# %%
df_dhaka=df_dhaka.drop("OBJECTID", axis='columns')

# %%
df_dhaka.count()
# Out:
# Surface_area                  632745
# Potential_installable_area    632745
# Peak_installable_capacity     632745
# Energy_potential_per_year     632745
# Assumed_building_type         632745
# Estimated_tilt                632745
# Estimated_building_height     627490
# Estimated_capacity_factor     623809
# dtype: int64

# %%
df_dhaka.head()
# Out:
#    Surface_area  Potential_installable_area  Peak_installable_capacity  \
# 0    331.500000                  189.410004                  36.779999
# 1     22.030001                    6.840000                   1.330000
# 2     23.930000                    9.230000                   1.790000
# 3     56.299999                   31.379999                   6.090000
# 4     74.290001                   34.169998                   6.630000
#
#    Energy_potential_per_year      Assumed_building_type  Estimated_tilt  \
# 0               48073.441406                 commercial            3.64
# 1                1635.270020  single family residential           11.71
# 2                2339.199951  single family residential            1.14
# 3                7957.629883  single family residential            7.04
# 4                7786.689941  single family residential           14.52
#
#    Estimated_building_height  Estimated_capacity_factor
# ...

# %%
df_dhaka.rename(columns = {'Surface_area':'surface_area', 
                     'Potential_installable_area':'installable_area', 
                     'Peak_installable_capacity':'capacity', 
                     'Energy_potential_per_year':'energy_year',
                     'Assumed_building_type':'building', 
                     'Estimated_tilt':'tilt', 
                     'Estimated_building_height':'height', 
                     'Estimated_capacity_factor':'capacity_factor'}, inplace = True)

# %%
df_dhaka.columns
# Out:
# Index(['surface_area', 'installable_area', 'capacity', 'energy_year',
#        'building', 'tilt', 'height', 'capacity_factor'],
#       dtype='object')

# %%
df_dhaka['height'].isna().sum()
# Out:
# np.int64(5255)

# %%
df_dhaka[df_dhaka['height'].isna()]
# Out:
#         surface_area  installable_area  capacity   energy_year  \
# 2585       80.559998         45.720001      8.87  11538.629883
# 9147      172.199997         93.650002     18.17  23582.519531
# 9177       58.750000         22.629999      4.39   5698.810059
# 9179      124.050003         75.400002     14.63  18987.099609
# 9180       71.320000         39.110001      7.59   9848.919922
# ...              ...               ...       ...           ...
# 632545     10.060000          3.540000      0.69    894.619995
# 632546     29.280001         13.800000      2.68   3491.479980
# 632547     43.230000         22.950001      4.45   5806.140137
# 632548    102.779999         62.630001     12.15  15843.990234
# 632549     32.810001         15.880000      3.08   4017.600098
#
#                          building  tilt  height  capacity_factor
# 2585    single family residential   0.0     NaN           1301.0
# 9147    single family residential   0.0     NaN           1298.0
# ...

# %%
df_dhaka['height'].describe()
# Out:
# count    627490.000000
# mean          8.463833
# std          77.982919
# min       -3678.020000
# 25%           3.000000
# 50%           5.630000
# 75%          12.610000
# max        3560.780000
# Name: height, dtype: float64

# %%
df_dhaka[df_dhaka['height'] < 0]
# Out:
#         surface_area  installable_area  capacity  energy_year  \
# 124        19.180000              6.26      1.21  1587.430054
# 520        24.350000              0.00      0.00     0.000000
# 747        52.180000             21.59      4.19  5474.830078
# 3500       29.559999              7.97      1.55  1996.589966
# 5020       22.770000              9.64      1.87  2070.760010
# ...              ...               ...       ...          ...
# 632713     12.450000              4.73      0.92  1187.250000
# 632714     19.000000              8.15      1.58  2046.689941
# 632716     19.980000              9.03      1.75  2266.979980
# 632717     13.670000              2.57      0.50   644.390015
# 632718     35.529999             18.25      3.54  4581.669922
#
#                          building   tilt  height  capacity_factor
# 124     single family residential   4.47   -0.19           1307.0
# 520     single family residential  28.66   -0.30              NaN
# ...

# %%
df_dhaka.loc[df_dhaka['height'] < 0, 'height'] = np.nan

# %%
df_dhaka.loc[df_dhaka['height'] == 0, 'height']
# Out:
# 26        0.0
# 44        0.0
# 45        0.0
# 46        0.0
# 47        0.0
#          ...
# 612473    0.0
# 613104    0.0
# 628524    0.0
# 628894    0.0
# 632711    0.0
# Name: height, Length: 3902, dtype: float64

# %%
df_dhaka.loc[df_dhaka['height'] == 0, 'height'] = np.nan

# %%
df_dhaka['height'].describe()
# Out:
# count    613030.000000
# mean         10.720692
# std          52.746042
# min           0.010000
# 25%           3.120000
# 50%           5.830000
# 75%          12.850000
# max        3560.780000
# Name: height, dtype: float64

# %%
mean_height = df_dhaka['height'].mean()
median_height =df_dhaka['height'].median()

print("Mean height:", mean_height)
print("Median height:", median_height)
# Out:
# Mean height: 10.720692037910053
# Median height: 5.83

# %%
df_dhaka['height']=df_dhaka['height'].fillna(median_height) # max ouliter can affect mean, so I choose median

# %%
df_dhaka['height'].isna().sum()
# Out:
# np.int64(0)

# %%
df_dhaka['capacity_factor'].isna().sum()
# Out:
# np.int64(8936)

# %%
df_dhaka.count()
# Out:
# surface_area        632745
# installable_area    632745
# capacity            632745
# energy_year         632745
# building            632745
# tilt                632745
# height              632745
# capacity_factor     623809
# dtype: int64

# %%
df_dhaka[df_dhaka['capacity_factor'].isna()]
# Out:
#         surface_area  installable_area  capacity  energy_year  \
# 99         35.700001               0.0       0.0          0.0
# 199        30.799999               0.0       0.0          0.0
# 236        37.230000               0.0       0.0          0.0
# 267        11.500000               0.0       0.0          0.0
# 310        24.799999               0.0       0.0          0.0
# ...              ...               ...       ...          ...
# 632654     22.770000               0.0       0.0          0.0
# 632679     19.440001               0.0       0.0          0.0
# 632699      7.250000               0.0       0.0          0.0
# 632720      9.980000               0.0       0.0          0.0
# 632736     14.560000               0.0       0.0          0.0
#
#                          building       tilt  height  capacity_factor
# 99      single family residential  18.790001    4.60              NaN
# 199     single family residential  28.420000    1.82              NaN
# ...

# %%
df_dhaka['capacity_factor'].describe()
# Out:
# count    623809.000000
# mean       1226.994538
# std          77.479822
# min         854.000000
# 25%        1173.119995
# 50%        1245.150024
# 75%        1298.000000
# max        1318.000000
# Name: capacity_factor, dtype: float64

# %%
df_dhaka = df_dhaka.dropna(subset=['capacity_factor'])

# %%
df_dhaka['capacity_factor'].isna().sum()
# Out:
# np.int64(0)

# %%
df_dhaka.count()
# Out:
# surface_area        623809
# installable_area    623809
# capacity            623809
# energy_year         623809
# building            623809
# tilt                623809
# height              623809
# capacity_factor     623809
# dtype: int64

# %%
df_dhaka.head()
# Out:
#    surface_area  installable_area   capacity   energy_year  \
# 0    331.500000        189.410004  36.779999  48073.441406
# 1     22.030001          6.840000   1.330000   1635.270020
# 2     23.930000          9.230000   1.790000   2339.199951
# 3     56.299999         31.379999   6.090000   7957.629883
# 4     74.290001         34.169998   6.630000   7786.689941
#
#                     building   tilt  height  capacity_factor
# 0                 commercial   3.64    5.75       1307.00000
# 1  single family residential  11.71    2.71       1233.00000
# 2  single family residential   1.14    3.33       1307.00000
# 3  single family residential   7.04    3.34       1307.00000
# 4  single family residential  14.52    4.47       1174.47998

# %%
sns.countplot(df_dhaka, x = 'building')
# Out:
# <Axes: xlabel='building', ylabel='count'>

# %%
sns.boxplot(x = df_dhaka["building"], y = df_dhaka["capacity"])
plt.ylabel("Peak Capacity")
plt.xlabel("Building Type")
# Out:
# Text(0.5, 0, 'Building Type')

# %%
sns.scatterplot(x = df_dhaka['installable_area'], y = df_dhaka['capacity'], hue=df_dhaka['building'])
plt.ylabel("Peak Capacity")
plt.xlabel("Installable Area of Rooftop")
# Out:
# Text(0.5, 0, 'Installable Area of Rooftop')

# %%
sns.scatterplot(x = df_dhaka['tilt'], y = df_dhaka['capacity'], hue=df_dhaka['building'])
plt.ylabel("Peak Capacity")
plt.xlabel("Tilt Angle")
# Out:
# Text(0.5, 0, 'Tilt Angle')

# %%
sns.scatterplot(x = df_dhaka['building'], y = df_dhaka['installable_area'], hue=df_dhaka['tilt'])
plt.ylabel("Installable Area")
plt.xlabel("Building Type")
# Out:
# Text(0.5, 0, 'Building Type')

# %%
sns.scatterplot(x = df_dhaka['height'], y = df_dhaka['capacity'], hue=df_dhaka['building'])
plt.ylabel("Peak Capacity")
plt.xlabel("Building Height")
# Out:
# Text(0.5, 0, 'Building Height')

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df_dhaka["building"] = le.fit_transform(df_dhaka["building"])

df_dhaka["building"].unique()
# Out:
# array([0, 4, 3, 5, 2, 1])

# %%
plt.figure(figsize = (15,8))
sns.heatmap(df_dhaka.corr(), annot=True, cmap="coolwarm")
# Out:
# <Axes: >
