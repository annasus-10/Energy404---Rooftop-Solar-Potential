# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('original_datasets\panama8cities_rooftop_solar_potential.csv')
df.head()
# Out:
#                                    uuid  Latitude  Longitude    City  \
# 0  19afda72-1f28-437e-b31f-ec25a25f27b7  9.354775 -79.845839  Panama
# 1  bf4ec591-e644-49fb-9f65-73370cb77d0e  9.341424 -79.863225  Panama
# 2  8bd2158b-0d7e-4284-8a8b-7ecc203fe456  9.354814 -79.859454  Panama
# 3  b0afdc31-4f2f-4f0e-b1b7-8ac62e9e9412  9.354977 -79.899122  Panama
# 4  41359694-2584-47e1-911c-db36e9cc63ee  9.355040 -79.898871  Panama
#
#    Surface_area  Potential_installable_area  Peak_installable_capacity  \
# 0         66.95                       35.59                       6.90
# 1        321.32                      203.99                      39.57
# 2         65.97                       26.77                       5.19
# 3        118.30                       64.17                      12.45
# 4        248.64                      180.38                      34.96
#
#    Energy_potential_per_year      Assumed_building_type  Estimated_tilt  \
# 0                    9262.28  Single-family residential           14.14
# 1                   50579.23  Single-family residential           15.87
# 2                    6621.64  Single-family residential           16.03
# 3                   16955.48   Multi-family residential           14.77
# 4                   47165.99   Multi-family residential           13.30
#
#    Estimated_building_height  Estimated_capacity_factor  \
# 0                      16.02                    1341.62
# 1                       4.20                    1278.08
# 2                       5.97                    1275.00
# 3                      11.23                    1362.00
# 4                      11.50                    1349.17
#
#    Estimated_Installation_Efficiency  Unit_installation_price  Date_added  \
# 0                             138.35                      NaN         NaN
# 1                             157.41                      NaN         NaN
# 2                             100.38                      NaN         NaN
# 3                             143.33                      NaN         NaN
# 4                             189.70                      NaN         NaN
#
#      aoi roof_quality  Comment
# 0  Colon          low      NaN
# 1  Colon         high      NaN
# 2  Colon          low      NaN
# 3  Colon          low      NaN
# 4  Colon          low      NaN

# %%
df.tail()
# Out:
#                                         uuid  Latitude  Longitude    City  \
# 189849  e1085e99-e299-40c6-8d5c-3e5ed32ae6d0  9.051430 -79.499140  Panama
# 189850  43d0ee17-d439-4174-8890-688ae9421181  9.051397 -79.480758  Panama
# 189851  896f1da5-c535-47a1-bf4f-2a8743373f4c  9.051428 -79.494080  Panama
# 189852  dce82b42-f594-406e-8979-7a5d19c7cf57  9.051413 -79.489443  Panama
# 189853  e184f370-98cf-4e00-a0c9-8058db955a29  9.051404 -79.484399  Panama
#
#         Surface_area  Potential_installable_area  Peak_installable_capacity  \
# 189849          5.10                        0.00                       0.00
# 189850        137.44                       85.83                      16.65
# 189851         56.53                       27.95                       5.42
# 189852         63.94                       36.31                       7.04
# 189853         94.53                       56.09                      10.88
#
#         Energy_potential_per_year      Assumed_building_type  Estimated_tilt  \
# 189849                       0.00  Single-family residential             0.0
# 189850                   22760.95  Single-family residential             0.0
# 189851                    7428.88  Single-family residential             0.0
# 189852                    9650.46  Single-family residential             0.0
# 189853                   14907.02                     Public             0.0
#
#         Estimated_building_height  Estimated_capacity_factor  \
# 189849                        NaN                        NaN
# 189850                        NaN                     1367.0
# 189851                        NaN                     1370.0
# 189852                        NaN                     1370.0
# 189853                        NaN                     1370.0
#
#         Estimated_Installation_Efficiency  Unit_installation_price  \
# 189849                               0.00                      NaN
# 189850                             165.61                      NaN
# 189851                             131.41                      NaN
# 189852                             150.94                      NaN
# 189853                             157.69                      NaN
#
#         Date_added          aoi roof_quality  Comment
# 189849         NaN  Panama City       medium      NaN
# 189850         NaN  Panama City       medium      NaN
# 189851         NaN  Panama City       medium      NaN
# 189852         NaN  Panama City       medium      NaN
# 189853         NaN  Panama City       medium      NaN

# %%
df.shape
# Out:
# (189854, 18)

# %%
df.describe()
# Out:
#             Latitude      Longitude   Surface_area  \
# count  189854.000000  189854.000000  189854.000000
# mean        8.724342     -80.335814     209.291251
# std         0.488606       1.118978     642.030217
# min         7.734464     -82.457564       0.170000
# 25%         8.415110     -80.434047      62.400000
# 50%         8.993235     -79.865454     127.030000
# 75%         9.039980     -79.511448     213.790000
# max         9.374751     -78.135838  128651.800000
#
#        Potential_installable_area  Peak_installable_capacity  \
# count               189854.000000              189854.000000
# mean                   135.883176                  26.361504
# std                    481.863525                  93.487613
# min                      0.000000                   0.000000
# 25%                     31.490000                   6.110000
# 50%                     72.750000                  14.110000
# 75%                    129.590000                  25.140000
# max                  98014.200000               19014.750000
#
#        Energy_potential_per_year  Estimated_tilt  Estimated_building_height  \
# count               1.898540e+05   189854.000000              172007.000000
# mean                3.630781e+04       15.653098                   5.880420
# std                 1.294476e+05        6.215859                   5.346549
# min                 0.000000e+00        0.000000                   2.000000
# 25%                 8.531157e+03       13.770000                   3.020000
# 50%                 1.961347e+04       16.290000                   3.930000
# 75%                 3.450745e+04       19.070000                   6.740000
# max                 2.643051e+07       40.940000                  98.940000
#
#        Estimated_capacity_factor  Estimated_Installation_Efficiency  \
# count              188460.000000                      189854.000000
# mean                 1386.964350                         150.860992
# std                    81.266843                          33.673766
# min                  1063.000000                           0.000000
# 25%                  1327.990000                         134.810000
# 50%                  1373.000000                         155.190000
# 75%                  1458.000000                         170.930000
# max                  1549.000000                         242.250000
#
#        Unit_installation_price  Date_added  Comment
# count                      0.0         0.0      0.0
# mean                       NaN         NaN      NaN
# std                        NaN         NaN      NaN
# min                        NaN         NaN      NaN
# 25%                        NaN         NaN      NaN
# 50%                        NaN         NaN      NaN
# 75%                        NaN         NaN      NaN
# max                        NaN         NaN      NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 589629 entries, 0 to 589628
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   uuid                        589629 non-null  object
#  1   City                        589629 non-null  object
#  2   Surface_area                589629 non-null  float64
#  3   Potential_installable_area  589629 non-null  float64
#  4   Peak_installable_capacity   589629 non-null  float64
#  5   Energy_potential_per_year   589629 non-null  float64
#  6   Assumed_building_type       589629 non-null  object
#  7   Estimated_tilt              589629 non-null  float64
#  8   Estimated_building_height   587547 non-null  float64
#  9   Estimated_capacity_factor   506631 non-null  float64
#  10  Unit_installation_price     0 non-null       float64
#  11  Comment                     0 non-null       float64
# dtypes: float64(9), object(3)
# memory usage: 54.0+ MB

# %%
df.columns
# Out:
# Index(['uuid', 'Latitude', 'Longitude', 'City', 'Surface_area',
#        'Potential_installable_area', 'Peak_installable_capacity',
#        'Energy_potential_per_year', 'Assumed_building_type', 'Estimated_tilt',
#        'Estimated_building_height', 'Estimated_capacity_factor',
#        'Estimated_Installation_Efficiency', 'Unit_installation_price',
#        'Date_added', 'aoi', 'roof_quality', 'Comment'],
#       dtype='object')

# %%
df.nunique().sort_values()
# Out:
# Unit_installation_price                   0
# Date_added                                0
# Comment                                   0
# City                                      1
# roof_quality                              3
# Assumed_building_type                     8
# aoi                                       8
# Estimated_tilt                         2993
# Estimated_building_height              3691
# Peak_installable_capacity             13897
# Estimated_Installation_Efficiency     17514
# Estimated_capacity_factor             29263
# Potential_installable_area            37018
# Surface_area                          47671
# Energy_potential_per_year            185175
# Latitude                             189828
# Longitude                            189840
# uuid                                 189854
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df.isnull().sum())
# Out:
# uuid                                      0
# Latitude                                  0
# Longitude                                 0
# City                                      0
# Surface_area                              0
# Potential_installable_area                0
# Peak_installable_capacity                 0
# Energy_potential_per_year                 0
# Assumed_building_type                     0
# Estimated_tilt                            0
# Estimated_building_height             17847
# Estimated_capacity_factor              1394
# Estimated_Installation_Efficiency         0
# Unit_installation_price              189854
# Date_added                           189854
# aoi                                       0
# roof_quality                              0
# Comment                              189854
# dtype: int64

# %%
rules = {
    'Surface_area': (0, np.inf),
    'Potential_installable_area': (0, np.inf),
    'Peak_installable_capacity': (0, np.inf),      # kWp
    'Energy_potential_per_year': (0, np.inf),      # kWh/year
    'Estimated_tilt': (0, 90),                     # degrees
    'Estimated_building_height': (0, np.inf),
    'Estimated_capacity_factor': (0, 1),           # 0–1
    'Estimated_installation_efficiency': (0, 1),   # 0–1
    'Unit_installation_price': (0, np.inf)
}
violations = {}
for col,(lo,hi) in rules.items():
    if col in df.columns:
        violations[col] = df[(df[col].notna()) & ((df[col]<lo)|(df[col]>hi))].shape[0]
violations
# Out:
# {'Surface_area': 0,
#  'Potential_installable_area': 0,
#  'Peak_installable_capacity': 0,
#  'Energy_potential_per_year': 0,
#  'Estimated_tilt': 0,
#  'Estimated_building_height': 0,
#  'Estimated_capacity_factor': 188460,
#  'Unit_installation_price': 0}

# %%
# Drop useless columns
df.drop(['Unit_installation_price','Date_added', 'City', 'Comment'], axis=1, inplace=True)

# %%
df[df['Estimated_building_height'] <= 0][['Estimated_building_height']].describe()
# Out:
#        Estimated_building_height
# count                        0.0
# mean                         NaN
# std                          NaN
# min                          NaN
# 25%                          NaN
# 50%                          NaN
# 75%                          NaN
# max                          NaN

# %%
df.loc[df['Estimated_building_height'] <= 0, 'Estimated_building_height'] = np.nan

# %%
df['Estimated_building_height'].fillna(df['Estimated_building_height'].median(), inplace=True)

# %%
df['Estimated_building_height'] = df['Estimated_building_height'] / 100

# %%
df['Estimated_capacity_factor'].describe()
# Out:
# count    188460.000000
# mean       1386.964350
# std          81.266843
# min        1063.000000
# 25%        1327.990000
# 50%        1373.000000
# 75%        1458.000000
# max        1549.000000
# Name: Estimated_capacity_factor, dtype: float64

# %%
df['Estimated_capacity_factor'] = df['Estimated_capacity_factor'] / 1000

# %%
df['Estimated_capacity_factor'].describe()
# Out:
# count    188460.000000
# mean          1.386964
# std           0.081267
# min           1.063000
# 25%           1.327990
# 50%           1.373000
# 75%           1.458000
# max           1.549000
# Name: Estimated_capacity_factor, dtype: float64

# %%
df['Estimated_capacity_factor'] = df['Estimated_capacity_factor'].clip(upper=1)

# %%
rules = {
    'Surface_area': (0, np.inf),
    'Potential_installable_area': (0, np.inf),
    'Peak_installable_capacity': (0, np.inf),      # kWp
    'Energy_potential_per_year': (0, np.inf),      # kWh/year
    'Estimated_tilt': (0, 90),                     # degrees
    'Estimated_building_height': (0, np.inf),
    'Estimated_capacity_factor': (0, 1),           # 0–1
    'Estimated_installation_efficiency': (0, 1),   # 0–1
    'Unit_installation_price': (0, np.inf)
}
violations = {}
for col,(lo,hi) in rules.items():
    if col in df.columns:
        violations[col] = df[(df[col].notna()) & ((df[col]<lo)|(df[col]>hi))].shape[0]
violations
# Out:
# {'Surface_area': 0,
#  'Potential_installable_area': 0,
#  'Peak_installable_capacity': 0,
#  'Energy_potential_per_year': 0,
#  'Estimated_tilt': 0,
#  'Estimated_building_height': 0,
#  'Estimated_capacity_factor': 0}

# %%
print(df.isnull().sum())
# Out:
# uuid                                    0
# Latitude                                0
# Longitude                               0
# Surface_area                            0
# Potential_installable_area              0
# Peak_installable_capacity               0
# Energy_potential_per_year               0
# Assumed_building_type                   0
# Estimated_tilt                          0
# Estimated_building_height               0
# Estimated_capacity_factor            1394
# Estimated_Installation_Efficiency       0
# aoi                                     0
# roof_quality                            0
# dtype: int64

# %%
# drop missing values
df = df.dropna(subset=['Estimated_capacity_factor'])

# %%
print(df.isnull().sum())
# Out:
# uuid                                 0
# Latitude                             0
# Longitude                            0
# Surface_area                         0
# Potential_installable_area           0
# Peak_installable_capacity            0
# Energy_potential_per_year            0
# Assumed_building_type                0
# Estimated_tilt                       0
# Estimated_building_height            0
# Estimated_capacity_factor            0
# Estimated_Installation_Efficiency    0
# aoi                                  0
# roof_quality                         0
# dtype: int64

# %%
sns.countplot(data=df, x='Assumed_building_type')
# Out:
# <Axes: xlabel='Assumed_building_type', ylabel='count'>

# %%
sns.displot(data = df, x = 'Energy_potential_per_year')

# %%
sns.displot(data = df, x = 'Peak_installable_capacity')

# %%
#Univariate Distributions

num_cols = df.select_dtypes(include=[np.number]).columns
for c in ['Surface_area','Potential_installable_area','Peak_installable_capacity',
          'Energy_potential_per_year','Estimated_tilt','Estimated_capacity_factor',
          'Estimated_installation_efficiency','Unit_installation_price']:
    if c in num_cols:
        df[c].plot(kind='hist', bins=30, edgecolor='white')
        plt.title(c); plt.xlabel(c); plt.show()

# %%
def iqr_flags(s, k=1.5):
    q1, q3 = s.quantile([0.25,0.75])
    iqr = q3-q1
    return ((s < q1 - k*iqr) | (s > q3 + k*iqr))

outlier_report = {}
for c in num_cols:
    flags = iqr_flags(df[c].dropna())
    outlier_report[c] = int(flags.sum())
outlier_report
# Out:
# {'Latitude': 0,
#  'Longitude': 38481,
#  'Surface_area': 12827,
#  'Potential_installable_area': 15006,
#  'Peak_installable_capacity': 15000,
#  'Energy_potential_per_year': 14739,
#  'Estimated_tilt': 29216,
#  'Estimated_building_height': 17951,
#  'Estimated_capacity_factor': 0,
#  'Estimated_Installation_Efficiency': 5755}

# %%
cat_cols = df.select_dtypes(include=['object','category']).columns
for c in ['Assumed_building_type','roof_quality','aoi']:
    if c in df.columns:
        print(c, df[c].nunique())
        print(df[c].value_counts().head(10))
# Out:
# Assumed_building_type 8
# Assumed_building_type
# Single-family residential    154251
# Commercial                    19453
# Public                         3774
# Multi-family residential       3367
# Schools                        2968
# Industrial                     1934
# Public health facilities       1797
# Hotels                          916
# Name: count, dtype: int64
# roof_quality 3
# roof_quality
# low       72362
# high      69352
# medium    46746
# Name: count, dtype: int64
# aoi 8
# aoi
# Panama City              84036
# David                    35565
# Chitre Herrera           24389
# Colon                    23905
# Los Santos Las Tablas    10727
# Penonome                  5860
# Bocas del Toro            2916
# Darien La Palma           1062
# Name: count, dtype: int64

# %%
df['Assumed_building_type'] = df['Assumed_building_type'].astype('category').cat.codes

# %%
df['roof_quality'] = df['roof_quality'].astype('category').cat.codes

# %%
df['aoi'] = df['aoi'].astype('category').cat.codes

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 188460 entries, 0 to 189853
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   uuid                               188460 non-null  object
#  1   Latitude                           188460 non-null  float64
#  2   Longitude                          188460 non-null  float64
#  3   Surface_area                       188460 non-null  float64
#  4   Potential_installable_area         188460 non-null  float64
#  5   Peak_installable_capacity          188460 non-null  float64
#  6   Energy_potential_per_year          188460 non-null  float64
#  7   Assumed_building_type              188460 non-null  int8
#  8   Estimated_tilt                     188460 non-null  float64
#  9   Estimated_building_height          188460 non-null  float64
#  10  Estimated_capacity_factor          188460 non-null  float64
#  11  Estimated_Installation_Efficiency  188460 non-null  float64
#  12  aoi                                188460 non-null  int8
#  13  roof_quality                       188460 non-null  int8
# dtypes: float64(10), int8(3), object(1)
# memory usage: 17.8+ MB
#                                    uuid  Latitude  Longitude  Surface_area  \
# 0  19afda72-1f28-437e-b31f-ec25a25f27b7  9.354775 -79.845839         66.95
# 1  bf4ec591-e644-49fb-9f65-73370cb77d0e  9.341424 -79.863225        321.32
# 2  8bd2158b-0d7e-4284-8a8b-7ecc203fe456  9.354814 -79.859454         65.97
# 3  b0afdc31-4f2f-4f0e-b1b7-8ac62e9e9412  9.354977 -79.899122        118.30
# 4  41359694-2584-47e1-911c-db36e9cc63ee  9.355040 -79.898871        248.64
#
#    Potential_installable_area  Peak_installable_capacity  \
# 0                       35.59                       6.90
# 1                      203.99                      39.57
# 2                       26.77                       5.19
# 3                       64.17                      12.45
# 4                      180.38                      34.96
#
#    Energy_potential_per_year  Assumed_building_type  Estimated_tilt  \
# 0                    9262.28                      7           14.14
# 1                   50579.23                      7           15.87
# 2                    6621.64                      7           16.03
# 3                   16955.48                      3           14.77
# 4                   47165.99                      3           13.30
#
#    Estimated_building_height  Estimated_capacity_factor  \
# 0                     0.1602                        1.0
# 1                     0.0420                        1.0
# 2                     0.0597                        1.0
# 3                     0.1123                        1.0
# 4                     0.1150                        1.0
#
#    Estimated_Installation_Efficiency  aoi  roof_quality
# 0                             138.35    2             1
# 1                             157.41    2             0
# 2                             100.38    2             1
# 3                             143.33    2             1
# 4                             189.70    2             1

# %%
t2 = 'Energy_potential_per_year'
for c in ['Surface_area','Potential_installable_area',
          'Peak_installable_capacity','Estimated_tilt','Estimated_capacity_factor']:
    if c in df.columns:
        df.plot(kind='scatter', x=c, y=t2, alpha=0.4)
        plt.title(f'{c} vs {t2}')
        plt.show()

# %%
# Compute correlations (only numeric columns)
corr = df.corr(numeric_only=True)

# Set up the figure
plt.figure(figsize=(12, 8))

# Create heatmap with numbers
sns.heatmap(
    corr,
    cmap='coolwarm',       # color style
    annot=True,            # show correlation numbers
    fmt=".2f",             # format numbers to 2 decimal places
    linewidths=0.5         # thin lines between boxes
)

plt.title("Correlation Heatmap", fontsize=16)
plt.show()

# %%
corr = df[num_cols].corr(numeric_only=True)
plt.figure(figsize=(10,8))
plt.imshow(corr, cmap='coolwarm', vmin=-1, vmax=1)
plt.colorbar(); plt.title('Correlation Matrix'); plt.xticks(range(len(num_cols)), num_cols, rotation=90); plt.yticks(range(len(num_cols)), num_cols)
plt.tight_layout(); plt.show()

# Quick look at variables most correlated with each target
corr_target1 = corr['Energy_potential_per_year'].sort_values(ascending=False) if 'Energy_potential_per_year' in corr else None
corr_target2 = corr['Peak_installable_capacity'].sort_values(ascending=False) if 'Peak_installable_capacity' in corr else None
corr_target1, corr_target2
# Out:
# (Energy_potential_per_year            1.000000
#  Peak_installable_capacity            0.999531
#  Potential_installable_area           0.999529
#  Surface_area                         0.993330
#  Estimated_Installation_Efficiency    0.245383
#  Estimated_building_height            0.125941
#  Latitude                             0.080359
#  Longitude                            0.078567
#  Estimated_tilt                       0.003839
#  Estimated_capacity_factor                 NaN
#  Name: Energy_potential_per_year, dtype: float64,
#  Peak_installable_capacity            1.000000
#  Potential_installable_area           1.000000
#  Energy_potential_per_year            0.999531
#  Surface_area                         0.994852
#  Estimated_Installation_Efficiency    0.241897
#  Estimated_building_height            0.130913
#  Latitude                             0.088388
#  Longitude                            0.086776
#  Estimated_tilt                       0.007951
#  Estimated_capacity_factor                 NaN
#  Name: Peak_installable_capacity, dtype: float64)

# %% [markdown]
# #### The top predictors for Energy Potential per Year:
#
# 1️⃣ Peak_installable_capacity
# 2️⃣ Potential_installable_area
# 3️⃣ Surface_area
